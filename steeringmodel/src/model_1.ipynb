# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from keras import layers
import os
import pandas as pd
import cv2

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
dataset_folder = "C:\\Users\\Aashish\\Desktop\\steeringmodel\\dataset"
final_images_folder_path = os.path.join(dataset_folder, 'final_images')
final_data_csv_path = os.path.join(dataset_folder, 'final_data.csv')

final_data = pd.read_csv(final_data_csv_path)

# %%
final_data
# Out:
#           timestamp     angle  throttle     brake
# 0      147942421588  0.001745  0.395651  0.148135
# 1      147942421598  0.003491  0.397726  0.148806
# 2      147942421608  0.006981  0.410178  0.147951
# 3      147942421618  0.026180  0.423972  0.148425
# 4      147942421628  0.031416  0.427024  0.148623
# ...             ...       ...       ...       ...
# 16103  147942655685  0.015708  0.308934  0.146639
# 16104  147942655695  0.019199  0.308934  0.147234
# 16105  147942655705  0.017453  0.308202  0.146929
# 16106  147942655715  0.013963  0.305272  0.146960
# 16107  147942656300 -0.010472  0.149950  0.147097
#
# [16108 rows x 4 columns]

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16108 entries, 0 to 16107
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  16108 non-null  int64
#  1   angle      16108 non-null  float64
#  2   throttle   16108 non-null  float64
#  3   brake      16108 non-null  float64
# dtypes: float64(3), int64(1)
# memory usage: 503.5 KB

# %%
final_data[final_data['timestamp'] == 147942421608]
# Out:
#       timestamp     angle  throttle     brake
# 2  147942421608  0.006981  0.410178  0.147951

# %%
import os
import cv2
import tensorflow as tf
import pandas as pd

class Data:
    def __init__(self, final_images_folder_path, final_data) -> None:
        self.path = final_images_folder_path
        self.final_data = final_data
        self.data = []

    def make_training_data(self):
        for filename in os.listdir(self.path):
            if filename.endswith(".jpg") or filename.endswith(".png"):
                image_name_as_ts = os.path.splitext(filename)[0]
                data_row = self.final_data[self.final_data['timestamp'] == int(image_name_as_ts)]
                if not data_row.empty:
                    angle = data_row['angle'].iloc[0]
                    throttle = data_row['throttle'].iloc[0]
                    brake = data_row['brake'].iloc[0]
                    self.data.append((filename, angle, throttle, brake))

    def load_image(self, filename):
        image = cv2.imread(os.path.join(self.path, filename))
        image = cv2.resize(image, (640, 480))  # Resize image to 320x240
        image = image / 255.0  # Normalize image data
        return image

    def data_generator(self, data):
        for filename, angle, throttle, brake in data:
            image = self.load_image(filename)
            yield image, (angle, throttle, brake)

    def create_dataset(self, data, batch_size, shuffle=True):
        dataset = tf.data.Dataset.from_generator(
            lambda: self.data_generator(data),
            output_signature=(
                tf.TensorSpec(shape=(480, 640, 3), dtype=tf.float32),  # Corrected shape
                (
                    tf.TensorSpec(shape=(), dtype=tf.float32),
                    tf.TensorSpec(shape=(), dtype=tf.float32),
                    tf.TensorSpec(shape=(), dtype=tf.float32),
                )
            )
        )
        if shuffle:
            dataset = dataset.shuffle(buffer_size=len(data))
        dataset = dataset.batch(batch_size)
        dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
        return dataset

    def training_data(self, batch_size):
        data_train = self.data[:int((len(self.data) * 3) / 4)]
        return self.create_dataset(data_train, batch_size)

    def validation_data(self, batch_size):
        data_val = self.data[int((len(self.data) * 3) / 4):]
        return self.create_dataset(data_val, batch_size, shuffle=False)

# Usage example:





# To use with TensorFlow model
# model.fit(train_dataset, validation_data=val_dataset, epochs=num_epochs)

# %%
# class Data():
#     def __init__(self) -> None:
#         self.path = final_images_folder_path
#         self.data = []
#         self.data_train = []
#         self.data_val = []
#         self.data_test = []
#     def make_training_data(self):
#         for filename in os.listdir(self.path):
#             if filename.endswith(".jpg") or filename.endswith(".png"):
#                 image = cv2.imread(os.path.join(self.path,filename))
#                 # image = cv2.resize(image, (320,120))
#                 image = image / 255.0  # Normalize image data
#                 image_name_as_ts = os.path.splitext(filename)[0]

#                 # print(f"img is {image}")

#                 data_row = final_data[final_data['timestamp'] == int(image_name_as_ts)]
#                 if not data_row.empty:
#                     angle = data_row['angle'].iloc[0]
#                     throttle = data_row['throttle'].iloc[0]
#                     brake = data_row['brake'].iloc[0]
#                     self.data.append((image, angle, throttle, brake))
        
#     def training_data(self):
#         self.data_train = self.data[:int((len(self.data)*3)/4)]
#         return self.data_train
    
#          # return last 1/4 of total data
#     def validation_data(self):
#         self.data_val = self.data[int((len(self.data)*3)/4)+1:-1]
#         return self.data_val
    
#     def testing_data(self):
#         self.data_test = self.data[int(len(self.data)-1):]
#         return self.data_test

# %%
# data = Data()
# data.make_training_data()

# data_train = data.training_data()
# print(type(data_train[0][0]))

# %%
# Input layer
inputs = keras.Input(name='input_shape', shape=(480, 640, 3))

# Convolutional feature maps
x = layers.Conv2D(filters=24, kernel_size=(5, 5), strides=(2, 2), activation='relu')(inputs)
x = layers.Conv2D(filters=36, kernel_size=(5, 5), strides=(2, 2), activation='relu')(x)
x = layers.Conv2D(filters=48, kernel_size=(5, 5), strides=(2, 2), activation='relu')(x)
x = layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), activation='relu')(x)
x = layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), activation='relu')(x)

# Flatten layer
x = layers.Flatten()(x)

# Fully connected layers with dropouts for overfit protection
x = layers.Dense(units=512, activation='relu')(x)
x = layers.Dropout(rate=0.1)(x)
x = layers.Dense(units=100, activation='relu')(x)
x = layers.Dropout(rate=0.1)(x)
x = layers.Dense(units=50, activation='relu')(x)
x = layers.Dropout(rate=0.1)(x)
x = layers.Dense(units=10, activation='relu')(x)
x = layers.Dropout(rate=0.1)(x)

# Derive steering angle value from single output layer by point multiplication
steering_angle = layers.Dense(units=1, activation='linear')(x)
steering_angle = layers.Lambda(lambda X: tf.multiply(tf.atan(X), 2), name='steering_angle')(steering_angle)

# Derive throttle pressure value from single output layer by point multiplication
throttle_press = layers.Dense(units=1, activation='linear')(x)
throttle_press = layers.Lambda(lambda X: tf.multiply(tf.atan(X), 2), name='throttle_press')(throttle_press)

# Derive brake pressure value from single output by point multiplication
brake_pressure = layers.Dense(units=1, activation='linear')(x)
brake_pressure = layers.Lambda(lambda X: tf.multiply(tf.atan(X), 2), name='brake_pressure')(brake_pressure)

# Build and compile model
model = keras.Model(inputs=[inputs], outputs=[steering_angle, throttle_press, brake_pressure])
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss={'steering_angle': 'mse', 'throttle_press': 'mse', 'brake_pressure': 'mse'}
)

# Model summary
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_shape (InputLayer)       [(None, 480, 640, 3  0           []
#                                 )]
#
#  conv2d_45 (Conv2D)             (None, 238, 318, 24  1824        ['input_shape[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 117, 157, 36  21636       ['conv2d_45[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 57, 77, 48)   43248       ['conv2d_46[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 55, 75, 64)   27712       ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 53, 73, 64)   36928       ['conv2d_48[0][0]']
#
#  flatten_9 (Flatten)            (None, 247616)       0           ['conv2d_49[0][0]']
#
#  dense_30 (Dense)               (None, 512)          126779904   ['flatten_9[0][0]']
#
#  dropout_20 (Dropout)           (None, 512)          0           ['dense_30[0][0]']
#
#  dense_31 (Dense)               (None, 100)          51300       ['dropout_20[0][0]']
#
#  dropout_21 (Dropout)           (None, 100)          0           ['dense_31[0][0]']
#
#  dense_32 (Dense)               (None, 50)           5050        ['dropout_21[0][0]']
#
#  dropout_22 (Dropout)           (None, 50)           0           ['dense_32[0][0]']
#
#  dense_33 (Dense)               (None, 10)           510         ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)           (None, 10)           0           ['dense_33[0][0]']
#
#  dense_34 (Dense)               (None, 1)            11          ['dropout_23[0][0]']
#
#  dense_35 (Dense)               (None, 1)            11          ['dropout_23[0][0]']
#
#  dense_36 (Dense)               (None, 1)            11          ['dropout_23[0][0]']
#
#  steering_angle (Lambda)        (None, 1)            0           ['dense_34[0][0]']
#
#  throttle_press (Lambda)        (None, 1)            0           ['dense_35[0][0]']
#
#  brake_pressure (Lambda)        (None, 1)            0           ['dense_36[0][0]']
#
# ==================================================================================================
# Total params: 126,968,145
# Trainable params: 126,968,145
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x
# Out:
# <KerasTensor: shape=(None, 10) dtype=float32 (created by layer 'dropout_23')>

# %%
def train(model, name, data, epochs, steps, steps_val, batch_size):
    # Extract training and validation datasets
    train_dataset = data.training_data(batch_size)
    val_dataset = data.validation_data(batch_size)

    # Train the model using the datasets
    history = model.fit(train_dataset, validation_data=val_dataset, epochs=epochs, steps_per_epoch=steps, validation_steps=steps_val)

    # Save the model
    model.save(f'{name}.h5')
    return history

# %%
# Assuming final_images_folder_path and final_data are already defined
data = Data(final_images_folder_path, final_data)
data.make_training_data()

batch_size = 16
epochs = 25
steps_per_epoch = 20
validation_steps = 20

# Build and compile the model as shown previously

# Train the model
train(model, 'jaishreeram', data, epochs, steps_per_epoch, validation_steps, batch_size)
# Out:
# Epoch 1/25
# 20/20 [==============================] - 90s 329ms/step - loss: 2.1948 - steering_angle_loss: 0.7605 - throttle_press_loss: 0.8195 - brake_pressure_loss: 0.6148 - val_loss: 0.1666 - val_steering_angle_loss: 0.1027 - val_throttle_press_loss: 0.0584 - val_brake_pressure_loss: 0.0054
# Epoch 2/25
# 20/20 [==============================] - 5s 244ms/step - loss: 0.1292 - steering_angle_loss: 0.1087 - throttle_press_loss: 0.0155 - brake_pressure_loss: 0.0050 - val_loss: 0.1747 - val_steering_angle_loss: 0.1295 - val_throttle_press_loss: 0.0437 - val_brake_pressure_loss: 0.0015
# Epoch 3/25
# 20/20 [==============================] - 5s 238ms/step - loss: 0.1136 - steering_angle_loss: 0.0957 - throttle_press_loss: 0.0140 - brake_pressure_loss: 0.0040 - val_loss: 0.1665 - val_steering_angle_loss: 0.1332 - val_throttle_press_loss: 0.0332 - val_brake_pressure_loss: 7.4305e-05
# Epoch 4/25
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0911 - steering_angle_loss: 0.0785 - throttle_press_loss: 0.0100 - brake_pressure_loss: 0.0026 - val_loss: 0.1724 - val_steering_angle_loss: 0.1447 - val_throttle_press_loss: 0.0277 - val_brake_pressure_loss: 1.8604e-05
# Epoch 5/25
# 20/20 [==============================] - 5s 257ms/step - loss: 0.1216 - steering_angle_loss: 0.1082 - throttle_press_loss: 0.0109 - brake_pressure_loss: 0.0026 - val_loss: 0.1312 - val_steering_angle_loss: 0.1052 - val_throttle_press_loss: 0.0252 - val_brake_pressure_loss: 8.4263e-04
# Epoch 6/25
# 20/20 [==============================] - 5s 243ms/step - loss: 0.0888 - steering_angle_loss: 0.0775 - throttle_press_loss: 0.0091 - brake_pressure_loss: 0.0022 - val_loss: 0.1348 - val_steering_angle_loss: 0.1033 - val_throttle_press_loss: 0.0315 - val_brake_pressure_loss: 1.2842e-05
# Epoch 7/25
# 20/20 [==============================] - 5s 240ms/step - loss: 0.1303 - steering_angle_loss: 0.1198 - throttle_press_loss: 0.0090 - brake_pressure_loss: 0.0015 - val_loss: 0.1611 - val_steering_angle_loss: 0.1324 - val_throttle_press_loss: 0.0287 - val_brake_pressure_loss: 4.5553e-06
# Epoch 8/25
# 20/20 [==============================] - 5s 240ms/step - loss: 0.0990 - steering_angle_loss: 0.0891 - throttle_press_loss: 0.0085 - brake_pressure_loss: 0.0015 - val_loss: 0.1407 - val_steering_angle_loss: 0.1118 - val_throttle_press_loss: 0.0289 - val_brake_pressure_loss: 3.3083e-05
# Epoch 9/25
# 20/20 [==============================] - 5s 241ms/step - loss: 0.0817 - steering_angle_loss: 0.0715 - throttle_press_loss: 0.0087 - brake_pressure_loss: 0.0015 - val_loss: 0.1365 - val_steering_angle_loss: 0.1138 - val_throttle_press_loss: 0.0224 - val_brake_pressure_loss: 2.4610e-04
# Epoch 10/25
# 20/20 [==============================] - 5s 241ms/step - loss: 0.1370 - steering_angle_loss: 0.1284 - throttle_press_loss: 0.0075 - brake_pressure_loss: 0.0012 - val_loss: 0.1443 - val_steering_angle_loss: 0.1178 - val_throttle_press_loss: 0.0265 - val_brake_pressure_loss: 7.6137e-06
# Epoch 11/25
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0712 - steering_angle_loss: 0.0631 - throttle_press_loss: 0.0068 - brake_pressure_loss: 0.0012 - val_loss: 0.1470 - val_steering_angle_loss: 0.1180 - val_throttle_press_loss: 0.0288 - val_brake_pressure_loss: 1.8209e-04
# Epoch 12/25
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0910 - steering_angle_loss: 0.0803 - throttle_press_loss: 0.0097 - brake_pressure_loss: 0.0011 - val_loss: 0.1581 - val_steering_angle_loss: 0.1318 - val_throttle_press_loss: 0.0260 - val_brake_pressure_loss: 2.1487e-04
# Epoch 13/25
# 20/20 [==============================] - 5s 244ms/step - loss: 0.1004 - steering_angle_loss: 0.0915 - throttle_press_loss: 0.0078 - brake_pressure_loss: 0.0011 - val_loss: 0.1507 - val_steering_angle_loss: 0.1186 - val_throttle_press_loss: 0.0320 - val_brake_pressure_loss: 2.2866e-05
# Epoch 14/25
# 20/20 [==============================] - 5s 244ms/step - loss: 0.0836 - steering_angle_loss: 0.0746 - throttle_press_loss: 0.0078 - brake_pressure_loss: 0.0011 - val_loss: 0.1519 - val_steering_angle_loss: 0.1259 - val_throttle_press_loss: 0.0254 - val_brake_pressure_loss: 5.3304e-04
# Epoch 15/25
# 20/20 [==============================] - 5s 241ms/step - loss: 0.1035 - steering_angle_loss: 0.0947 - throttle_press_loss: 0.0077 - brake_pressure_loss: 0.0012 - val_loss: 0.1509 - val_steering_angle_loss: 0.1175 - val_throttle_press_loss: 0.0334 - val_brake_pressure_loss: 3.2331e-06
# Epoch 16/25
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0971 - steering_angle_loss: 0.0883 - throttle_press_loss: 0.0079 - brake_pressure_loss: 9.0122e-04 - val_loss: 0.1453 - val_steering_angle_loss: 0.1193 - val_throttle_press_loss: 0.0258 - val_brake_pressure_loss: 2.1991e-04
# Epoch 17/25
# 20/20 [==============================] - 5s 237ms/step - loss: 0.1091 - steering_angle_loss: 0.0996 - throttle_press_loss: 0.0086 - brake_pressure_loss: 8.2035e-04 - val_loss: 0.1372 - val_steering_angle_loss: 0.1118 - val_throttle_press_loss: 0.0253 - val_brake_pressure_loss: 1.2616e-04
# Epoch 18/25
# 20/20 [==============================] - 5s 237ms/step - loss: 0.0912 - steering_angle_loss: 0.0816 - throttle_press_loss: 0.0086 - brake_pressure_loss: 9.7071e-04 - val_loss: 0.1547 - val_steering_angle_loss: 0.1322 - val_throttle_press_loss: 0.0224 - val_brake_pressure_loss: 1.0702e-04
# Epoch 19/25
# 20/20 [==============================] - 5s 237ms/step - loss: 0.1567 - steering_angle_loss: 0.1483 - throttle_press_loss: 0.0075 - brake_pressure_loss: 9.2995e-04 - val_loss: 0.1480 - val_steering_angle_loss: 0.1162 - val_throttle_press_loss: 0.0317 - val_brake_pressure_loss: 1.2269e-04
# Epoch 20/25
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0889 - steering_angle_loss: 0.0795 - throttle_press_loss: 0.0086 - brake_pressure_loss: 8.0571e-04 - val_loss: 0.1399 - val_steering_angle_loss: 0.1144 - val_throttle_press_loss: 0.0253 - val_brake_pressure_loss: 2.0988e-04
# Epoch 21/25
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0850 - steering_angle_loss: 0.0764 - throttle_press_loss: 0.0076 - brake_pressure_loss: 9.7236e-04 - val_loss: 0.1489 - val_steering_angle_loss: 0.1229 - val_throttle_press_loss: 0.0259 - val_brake_pressure_loss: 9.9432e-05
# Epoch 22/25
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0686 - steering_angle_loss: 0.0600 - throttle_press_loss: 0.0077 - brake_pressure_loss: 8.0361e-04 - val_loss: 0.1482 - val_steering_angle_loss: 0.1234 - val_throttle_press_loss: 0.0246 - val_brake_pressure_loss: 1.8165e-04
# Epoch 23/25
# 20/20 [==============================] - 5s 237ms/step - loss: 0.1030 - steering_angle_loss: 0.0950 - throttle_press_loss: 0.0073 - brake_pressure_loss: 7.6673e-04 - val_loss: 0.1515 - val_steering_angle_loss: 0.1265 - val_throttle_press_loss: 0.0249 - val_brake_pressure_loss: 1.4292e-04
# Epoch 24/25
# 20/20 [==============================] - 5s 240ms/step - loss: 0.1196 - steering_angle_loss: 0.1122 - throttle_press_loss: 0.0067 - brake_pressure_loss: 7.0884e-04 - val_loss: 0.1369 - val_steering_angle_loss: 0.1106 - val_throttle_press_loss: 0.0262 - val_brake_pressure_loss: 1.7572e-04
# Epoch 25/25
# 20/20 [==============================] - 5s 239ms/step - loss: 0.0851 - steering_angle_loss: 0.0768 - throttle_press_loss: 0.0074 - brake_pressure_loss: 8.5138e-04 - val_loss: 0.1478 - val_steering_angle_loss: 0.1239 - val_throttle_press_loss: 0.0237 - val_brake_pressure_loss: 2.1686e-04

# %%
import cv2
import numpy as np
from keras.models import load_model

def preprocess_image(image_path):
    # Read the image
    image = cv2.imread(image_path)
    # Resize the image to match the expected input shape of the model
    image = cv2.resize(image, (640, 480))  # Correct dimensions
    # Normalize the pixel values to be in the range [0, 1]
    image = image.astype(np.float32) / 255.0
    # Expand dimensions to create a batch of one image
    image = np.expand_dims(image, axis=0)
    return image

def predict(image_paths, model_path):
    try:
        # Load the model
        model = load_model(model_path)
    except Exception as e:
        print("An unexpected error occurred:", e)
        print("Please check if the model file path is correct and the model file is not corrupted.")
        return None

    predictions = []
    for image_path in image_paths:
        # Preprocess the image
        preprocessed_image = preprocess_image(image_path)
        # Predict using the model
        prediction = model.predict(preprocessed_image)
        predictions.append(prediction)
    
    return predictions

# Example usage
test_image_paths = ["C:\\Users\\Aashish\\Desktop\\steeringmodel\\dataset\\center\\1479424259438336477.jpg"]
model_path = 'C:\\Users\\Aashish\\Desktop\\steeringmodel\\src\\jaishreeram.h5'
predictions = predict(test_image_paths, model_path)
if predictions is not None:
    print("Predictions:", predictions)
# Out:
# An unexpected error occurred: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:GPU:0}} failed to allocate memory [Op:Mul]
# Please check if the model file path is correct and the model file is not corrupted.

# %%
final_data[final_data['timestamp']==1479424201588]
# Out:
# Empty DataFrame
# Columns: [timestamp, angle, throttle, brake]
# Index: []
